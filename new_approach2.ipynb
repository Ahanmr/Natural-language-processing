# %%
import re
import pandas as pd
from nltk import word_tokenize
# df=pd.read_csv("test_sih.csv - Sheet1.csv")
# df.head(6)
test=str("hello! this is amazing #sih2019 [rcoer]")
print(word_tokenize(test))
test=re.sub('\W+',' ', test )
# import nltk

print(word_tokenize(test))
# Out:
# ['hello', '!', 'this', 'is', 'amazing', '#', 'sih2019', '[', 'rcoer', ']']
# ['hello', 'this', 'is', 'amazing', 'sih2019', 'rcoer']

# %%
df=pd.read_csv('pricelist.csv')
# df=pd.read_excel(df, 'sheet2')
df.head()
# Out:
#       PL No         Description
# 0  90354114     MS Flat 32x6 mm
# 1  90350868    MS Flat 30x12 mm
# 2  90350844  Flat Steel 50x8 mm
# 3  90350583     MS Flat 40x6 mm
# 4  90350212     MS FLat 25x6 mm

# %%
df["Description"][0].lower()
# Out:
# 'ms flat 32x6 mm'

# %%
df["TAGS"]=df["Description"]
for i in range(len(df["Description"])):
    df["TAGS"][i]=df["TAGS"][i].lower()
    df["TAGS"][i]=re.sub('\W+',' ', df["TAGS"][i])
    df["TAGS"][i]=word_tokenize(df["TAGS"][i])

df.head(6)
# Out:
# /home/ahanmr/flipkart/myvenv/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/ahanmr/flipkart/myvenv/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /home/ahanmr/flipkart/myvenv/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#       PL No             Description                           TAGS
# 0  90354114         MS Flat 32x6 mm           [ms, flat, 32x6, mm]
# 1  90350868        MS Flat 30x12 mm          [ms, flat, 30x12, mm]
# 2  90350844      Flat Steel 50x8 mm        [flat, steel, 50x8, mm]
# 3  90350583         MS Flat 40x6 mm           [ms, flat, 40x6, mm]
# 4  90350212         MS FLat 25x6 mm           [ms, flat, 25x6, mm]
# 5  90361714  MC STEEL HEX BAR 38 MM  [mc, steel, hex, bar, 38, mm]

# %%
df.head(20)
# Out:
#        PL No                                        Description  \
# 0   90354114                                    MS Flat 32x6 mm
# 1   90350868                                   MS Flat 30x12 mm
# 2   90350844                                 Flat Steel 50x8 mm
# 3   90350583                                    MS Flat 40x6 mm
# 4   90350212                                    MS FLat 25x6 mm
# 5   90361714                             MC STEEL HEX BAR 38 MM
# 6   90367170                         M C HEX BAR 23.81 MM STEEL
# 7   90361702                               M C HEX BAR(28.60MM)
# 8   90367170                         M C HEX BAR 23.81 MM STEEL
# 9   90210013                                   Cross Beam Small
# 10  90211066          STANDARD MEDIUM FLANGE BEAM 150 X75 X05MM
# 11  90701008                               M.S.WIRE 0.90 MM DIA
# 12  90701057       WIRE STEEL MILD GALVANISED 1.60 MM DIA,16SWG
# 13  90706950  wagon Sealing wire of soft mild steel Galvanis...
# 14  42012004                                     HREE PIN PLUG
# 15  42010019       Plug top, 3-pin, 5A/6 A, 230V/250V, 50Hz, AC
# 16  42010676       Plug top, 5-pin, 5A/6 A, 230V/250V, 50Hz, AC
# 17  42010690       Plug top, 6-pin, 5A/6 A, 230V/250V, 50Hz, AC
# 18  42020025  Switch Piano type, 5A/6A, 1 pole, 1-way, 230V/...
# 19  42029363                     10 Amps, 1 Way Modular Switch
#
#                                                  TAGS
# 0                                [ms, flat, 32x6, mm]
# 1                               [ms, flat, 30x12, mm]
# 2                             [flat, steel, 50x8, mm]
# 3                                [ms, flat, 40x6, mm]
# 4                                [ms, flat, 25x6, mm]
# 5                       [mc, steel, hex, bar, 38, mm]
# 6                 [m, c, hex, bar, 23, 81, mm, steel]
# 7                          [m, c, hex, bar, 28, 60mm]
# 8                 [m, c, hex, bar, 23, 81, mm, steel]
# 9                                [cross, beam, small]
# 10  [standard, medium, flange, beam, 150, x75, x05mm]
# 11                       [m, s, wire, 0, 90, mm, dia]
# 12  [wire, steel, mild, galvanised, 1, 60, mm, dia...
# 13  [wagon, sealing, wire, of, soft, mild, steel, ...
# 14                                  [hree, pin, plug]
# 15  [plug, top, 3, pin, 5a, 6, a, 230v, 250v, 50hz...
# 16  [plug, top, 5, pin, 5a, 6, a, 230v, 250v, 50hz...
# 17  [plug, top, 6, pin, 5a, 6, a, 230v, 250v, 50hz...
# 18  [switch, piano, type, 5a, 6a, 1, pole, 1, way,...
# 19                [10, amps, 1, way, modular, switch]

# %%
df
# Out:
#        PL No                                        Description  \
# 0   90354114                                    MS Flat 32x6 mm
# 1   90350868                                   MS Flat 30x12 mm
# 2   90350844                                 Flat Steel 50x8 mm
# 3   90350583                                    MS Flat 40x6 mm
# 4   90350212                                    MS FLat 25x6 mm
# 5   90361714                             MC STEEL HEX BAR 38 MM
# 6   90367170                         M C HEX BAR 23.81 MM STEEL
# 7   90361702                               M C HEX BAR(28.60MM)
# 8   90367170                         M C HEX BAR 23.81 MM STEEL
# 9   90210013                                   Cross Beam Small
# 10  90211066          STANDARD MEDIUM FLANGE BEAM 150 X75 X05MM
# 11  90701008                               M.S.WIRE 0.90 MM DIA
# 12  90701057       WIRE STEEL MILD GALVANISED 1.60 MM DIA,16SWG
# 13  90706950  wagon Sealing wire of soft mild steel Galvanis...
# 14  42012004                                     HREE PIN PLUG
# 15  42010019       Plug top, 3-pin, 5A/6 A, 230V/250V, 50Hz, AC
# 16  42010676       Plug top, 5-pin, 5A/6 A, 230V/250V, 50Hz, AC
# 17  42010690       Plug top, 6-pin, 5A/6 A, 230V/250V, 50Hz, AC
# 18  42020025  Switch Piano type, 5A/6A, 1 pole, 1-way, 230V/...
# 19  42029363                     10 Amps, 1 Way Modular Switch
# 20  42021131           Push Switch actuators with contact block
# 21  42021650  TOGGLE SWITCH 15 AMPS 250 VOLTS AC/DC, single ...
# 22  42027949      Power Contactor 630 Amps, 1000 V, 3 pole, AC
# 23  42114986                  TUBULAR FLOURESCENT LAMP 18 WATTS
# 24  42110221                                    LED BULB 5 WATT
# 25  42114986  Lamp flourescent day light Bi pin dimension 60...
# 26  42119182                             HALOGEN LAMP 24V, 100W
# 27  42114986                          ISI MARKED XLPE INSULATED
# 28  42502101  Electric Ceiling Fan Capacitor Type Sweep Size...
# 29  42500023  CABIN COOLING FAN SWEEP 300 MM WATTS 70 VOLTS ...
# ..       ...                                                ...
# 63  42012004  SYNTHETIC RESIN BONDED GLASS FIBRE (SRBGF) WOV...
# 64  92021025                               MOTOR SPIRIT ( PETRO
# 65  90367170                                    MS Flat 32x6 mm
# 66  42119182                                         BIO DIESEL
# 67  42012004       WIRE STEEL MILD GALVANISED 1.60 MM DIA,16SWG
# 68  92011205                                    MS Flat 40x6 mm
# 69  92022558       Plug top, 6-pin, 5A/6 A, 230V/250V, 50Hz, AC
# 70  42010019                                    LED BULB 5 WATT
# 71  41016853                 POLYSTER FILM FLAME-RETARDANT TAPE
# 72  42114986      Power Contactor 630 Amps, 1000 V, 3 pole, AC
# 73  42020025  Switch Piano type, 5A/6A, 1 pole, 1-way, 230V/...
# 74  42504020                                RTV SILICONE RUBBER
# 75  90354114                  300mm (12 INCH) SWEEP EXHAUST FAN
# 76  41013402                                   MS Flat 30x12 mm
# 77  90350868  SYNTHETIC RESIN BONDED GLASS FIBRE (SRBGF) WOV...
# 78  42021650                             MC STEEL HEX BAR 38 MM
# 79  90367170       Plug top, 5-pin, 5A/6 A, 230V/250V, 50Hz, AC
# 80  90210013                             MC STEEL HEX BAR 38 MM
# 81  42502101  wagon Sealing wire of soft mild steel Galvanis...
# 82  90354114          STANDARD MEDIUM FLANGE BEAM 150 X75 X05MM
# 83  42010019                               PVC SLEEV SIZE ID- 4
# 84  42029363                                 Flat Steel 50x8 mm
# 85  90350844                 POLYSTER FILM FLAME-RETARDANT TAPE
# 86  92112102  Lamp flourescent day light Bi pin dimension 60...
# 87  42119182                 POLYSTER FILM FLAME-RETARDANT TAPE
# 88  90701008                                    MS Flat 40x6 mm
# 89  90350583  TOGGLE SWITCH 15 AMPS 250 VOLTS AC/DC, single ...
# 90  42502101                                 PTFE BUSH/RING, IT
# 91  42012004       Plug top, 6-pin, 5A/6 A, 230V/250V, 50Hz, AC
# 92  41013402  SLEEVE PVC FLEXIBLE FOR ELECTRICAL PURPOSE 5.5...
#
#                                                  TAGS
# 0                                [ms, flat, 32x6, mm]
# 1                               [ms, flat, 30x12, mm]
# 2                             [flat, steel, 50x8, mm]
# 3                                [ms, flat, 40x6, mm]
# 4                                [ms, flat, 25x6, mm]
# 5                       [mc, steel, hex, bar, 38, mm]
# 6                 [m, c, hex, bar, 23, 81, mm, steel]
# 7                          [m, c, hex, bar, 28, 60mm]
# 8                 [m, c, hex, bar, 23, 81, mm, steel]
# 9                                [cross, beam, small]
# 10  [standard, medium, flange, beam, 150, x75, x05mm]
# 11                       [m, s, wire, 0, 90, mm, dia]
# 12  [wire, steel, mild, galvanised, 1, 60, mm, dia...
# 13  [wagon, sealing, wire, of, soft, mild, steel, ...
# 14                                  [hree, pin, plug]
# 15  [plug, top, 3, pin, 5a, 6, a, 230v, 250v, 50hz...
# 16  [plug, top, 5, pin, 5a, 6, a, 230v, 250v, 50hz...
# 17  [plug, top, 6, pin, 5a, 6, a, 230v, 250v, 50hz...
# 18  [switch, piano, type, 5a, 6a, 1, pole, 1, way,...
# 19                [10, amps, 1, way, modular, switch]
# 20    [push, switch, actuators, with, contact, block]
# 21  [toggle, switch, 15, amps, 250, volts, ac, dc,...
# 22  [power, contactor, 630, amps, 1000, v, 3, pole...
# 23            [tubular, flourescent, lamp, 18, watts]
# 24                               [led, bulb, 5, watt]
# 25  [lamp, flourescent, day, light, bi, pin, dimen...
# 26                         [halogen, lamp, 24v, 100w]
# 27                     [isi, marked, xlpe, insulated]
# 28  [electric, ceiling, fan, capacitor, type, swee...
# 29  [cabin, cooling, fan, sweep, 300, mm, watts, 7...
# ..                                                ...
# 63  [synthetic, resin, bonded, glass, fibre, srbgf...
# 64                             [motor, spirit, petro]
# 65                               [ms, flat, 32x6, mm]
# 66                                      [bio, diesel]
# 67  [wire, steel, mild, galvanised, 1, 60, mm, dia...
# 68                               [ms, flat, 40x6, mm]
# 69  [plug, top, 6, pin, 5a, 6, a, 230v, 250v, 50hz...
# 70                               [led, bulb, 5, watt]
# 71           [polyster, film, flame, retardant, tape]
# 72  [power, contactor, 630, amps, 1000, v, 3, pole...
# 73  [switch, piano, type, 5a, 6a, 1, pole, 1, way,...
# 74                            [rtv, silicone, rubber]
# 75             m, 12, inch, sweep, exhaust, fan]
# 76                              [ms, flat, 30x12, mm]
# 77  [synthetic, resin, bonded, glass, fibre, srbgf...
# 78                      [mc, steel, hex, bar, 38, mm]
# 79  [plug, top, 5, pin, 5a, 6, a, 230v, 250v, 50hz...
# 80                      [mc, steel, hex, bar, 38, mm]
# 81  [wagon, sealing, wire, of, soft, mild, steel, ...
# 82  [standard, medium, flange, beam, 150, x75, x05mm]
# 83                          [pvc, sleev, size, id, 4]
# 84                            [flat, steel, 50x8, mm]
# 85           [polyster, film, flame, retardant, tape]
# 86  [lamp, flourescent, day, light, bi, pin, dimen...
# 87           [polyster, film, flame, retardant, tape]
# 88                               [ms, flat, 40x6, mm]
# 89  [toggle, switch, 15, amps, 250, volts, ac, dc,...
# 90                             [ptfe, bush, ring, it]
# 91  [plug, top, 6, pin, 5a, 6, a, 230v, 250v, 50hz...
# 92  [sleeve, pvc, flexible, for, electrical, purpo...
#
# [93 rows x 3 columns]

# %%
df.to_csv("DATA_NEW_PRICELIST.csv")

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import euclidean_distances

# %%
corpus=[]
for i in range(len(df["DESCRIPTION"])):
    corpus.append(df["DESCRIPTION"][i])

# %%
# vectorizer=CountVectorizer()
# features=vectorizer.fit_transform(corpus).todense()
# print(features)

# %%
# vectorizer.vocabulary_

# %%
# featurelist=features.tolist()

# %%
# import numpy as np
# featurelist[0]=np.array(featurelist[0])
# featurelist[1]=np.array(featurelist[1])
# sum(abs(featurelist[0]-featurelist[3]))

# %%
from sklearn.utils import shuffle
df = shuffle(df)

# %%
from math import floor
split=floor(df.shape[0]*0.75)

# %%
df['group']=df['PL No']
df['subgroup']=df['PL No']
# Out:
# /home/ahanmr/flipkart/myvenv/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /home/ahanmr/flipkart/myvenv/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
str(df['subgroup'][0])[2:4]
# Out:
# '35'

# %%
for i in range(len(df['group'])):
    df['group'][i]=str(df['group'][i])[:2]
    df['subgroup'][i]=str(df['subgroup'][i])[2:4]
# Out:
# /home/ahanmr/flipkart/myvenv/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/ahanmr/flipkart/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3267: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /home/ahanmr/flipkart/myvenv/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
X=df.drop(["PL No"], axis=1)
Y=df["PL No"].tolist()

# %%
X_train=X[:split]
X_test=X[split:]
Y_train=Y[:split]
Y_test=Y[split:]

# %%
X_train
# Out:
#                                           Description  \
# 54                                        FURNACE OIL
# 8                          M C HEX BAR 23.81 MM STEEL
# 50                                      Foundary Coke
# 9                                    Cross Beam Small
# 17       Plug top, 6-pin, 5A/6 A, 230V/250V, 50Hz, AC
# 90                                 PTFE BUSH/RING, IT
# 83                               PVC SLEEV SIZE ID- 4
# 88                                    MS Flat 40x6 mm
# 3                                     MS Flat 40x6 mm
# 28  Electric Ceiling Fan Capacitor Type Sweep Size...
# 33  SYNTHETIC RESIN BONDED GLASS FIBRE (SRBGF) WOV...
# 65                                    MS Flat 32x6 mm
# 21  TOGGLE SWITCH 15 AMPS 250 VOLTS AC/DC, single ...
# 84                                 Flat Steel 50x8 mm
# 14                                     HREE PIN PLUG
# 2                                  Flat Steel 50x8 mm
# 66                                         BIO DIESEL
# 57                                    MS Flat 32x6 mm
# 61  CABIN COOLING FAN SWEEP 300 MM WATTS 70 VOLTS ...
# 23                  TUBULAR FLOURESCENT LAMP 18 WATTS
# 13  wagon Sealing wire of soft mild steel Galvanis...
# 62                                      THINNER - 231
# 27                          ISI MARKED XLPE INSULATED
# 12       WIRE STEEL MILD GALVANISED 1.60 MM DIA,16SWG
# 10          STANDARD MEDIUM FLANGE BEAM 150 X75 X05MM
# 6                          M C HEX BAR 23.81 MM STEEL
# 52                                     B.P.HARD COKE
# 72      Power Contactor 630 Amps, 1000 V, 3 pole, AC
# 82          STANDARD MEDIUM FLANGE BEAM 150 X75 X05MM
# 71                 POLYSTER FILM FLAME-RETARDANT TAPE
# ..                                                ...
# 73  Switch Piano type, 5A/6A, 1 pole, 1-way, 230V/...
# 37  Containing Iron -iso-maltoside 5ml vials injec...
# 75                  300mm (12 INCH) SWEEP EXHAUST FAN
# 69       Plug top, 6-pin, 5A/6 A, 230V/250V, 50Hz, AC
# 29  CABIN COOLING FAN SWEEP 300 MM WATTS 70 VOLTS ...
# 18  Switch Piano type, 5A/6A, 1 pole, 1-way, 230V/...
# 80                             MC STEEL HEX BAR 38 MM
# 64                               MOTOR SPIRIT ( PETRO
# 70                                    LED BULB 5 WATT
# 0                                     MS Flat 32x6 mm
# 7                                M C HEX BAR(28.60MM)
# 42             PVC SLEEVE ID- 15 MM THICKNESS 0.7 MM
# 77  SYNTHETIC RESIN BONDED GLASS FIBRE (SRBGF) WOV...
# 60          STANDARD MEDIUM FLANGE BEAM 150 X75 X05MM
# 59                         M C HEX BAR 23.81 MM STEEL
# 43                                 PTFE BUSH/RING, IT
# 40                               PVC SLEEV SIZE ID- 4
# 30  CAPACITOR FOR RC FAN 5 MED PLUS/MINUS 5 PERCEN...
# 34  EPOXY FIBRE GLASS SHEET 1200 X 1200 X3 MM GRAD...
# 55                               MOTOR SPIRIT ( PETRO
# 78                             MC STEEL HEX BAR 38 MM
# 19                     10 Amps, 1 Way Modular Switch
# 48                            HARD COKE ( FC )  150MM
# 86  Lamp flourescent day light Bi pin dimension 60...
# 11                               M.S.WIRE 0.90 MM DIA
# 38                     PVC SLEEVE I D =35 MM X 01 MM
# 41  Silicon Rubber Tape Type HTV-HBT-H5 Size: - 0....
# 45                                RTV SILICONE RUBBER
# 53                       Raw Petroleum Coke Chipped t
# 36      AMINATED SHEET (TOFNOL) SYNTHETIC RESING BOND
#
#                                                  TAGS  group  subgroup
# 54                                     [furnace, oil]     92        11
# 8                 [m, c, hex, bar, 23, 81, mm, steel]     90        36
# 50                                   [foundary, coke]     92         2
# 9                                [cross, beam, small]     90        21
# 17  [plug, top, 6, pin, 5a, 6, a, 230v, 250v, 50hz...     42         1
# 90                             [ptfe, bush, ring, it]     42        50
# 83                          [pvc, sleev, size, id, 4]     42         1
# 88                               [ms, flat, 40x6, mm]     90        70
# 3                                [ms, flat, 40x6, mm]     90        35
# 28  [electric, ceiling, fan, capacitor, type, swee...     42        50
# 33  [synthetic, resin, bonded, glass, fibre, srbgf...     41         1
# 65                               [ms, flat, 32x6, mm]     90        36
# 21  [toggle, switch, 15, amps, 250, volts, ac, dc,...     42         2
# 84                            [flat, steel, 50x8, mm]     42         2
# 14                                  [hree, pin, plug]     42         1
# 2                             [flat, steel, 50x8, mm]     90        35
# 66                                      [bio, diesel]     42        11
# 57                               [ms, flat, 32x6, mm]     90        36
# 61  [cabin, cooling, fan, sweep, 300, mm, watts, 7...     41        13
# 23            [tubular, flourescent, lamp, 18, watts]     42        11
# 13  [wagon, sealing, wire, of, soft, mild, steel, ...     90        70
# 62                                     [thinner, 231]     42        50
# 27                     [isi, marked, xlpe, insulated]     42        11
# 12  [wire, steel, mild, galvanised, 1, 60, mm, dia...     90        70
# 10  [standard, medium, flange, beam, 150, x75, x05mm]     90        21
# 6                 [m, c, hex, bar, 23, 81, mm, steel]     90        36
# 52                                 [b, p, hard, coke]     92         2
# 72  [power, contactor, 630, amps, 1000, v, 3, pole...     42        11
# 82  [standard, medium, flange, beam, 150, x75, x05mm]     90        35
# 71           [polyster, film, flame, retardant, tape]     41         1
# ..                                                ...    ...       ...
# 73  [switch, piano, type, 5a, 6a, 1, pole, 1, way,...     42         2
# 37  [containing, iron, iso, maltoside, 5ml, vials,...     41         1
# 75             m, 12, inch, sweep, exhaust, fan]     90        35
# 69  [plug, top, 6, pin, 5a, 6, a, 230v, 250v, 50hz...     92         2
# 29  [cabin, cooling, fan, sweep, 300, mm, watts, 7...     42        50
# 18  [switch, piano, type, 5a, 6a, 1, pole, 1, way,...     42         2
# 80                      [mc, steel, hex, bar, 38, mm]     90        21
# 64                             [motor, spirit, petro]     92         2
# 70                               [led, bulb, 5, watt]     42         1
# 0                                [ms, flat, 32x6, mm]     90        35
# 7                          [m, c, hex, bar, 28, 60mm]     90        36
# 42     [pvc, sleeve, id, 15, mm, thickness, 0, 7, mm]     41        11
# 77  [synthetic, resin, bonded, glass, fibre, srbgf...     90        35
# 60  [standard, medium, flange, beam, 150, x75, x05mm]     90        36
# 59                [m, c, hex, bar, 23, 81, mm, steel]     42         1
# 43                             [ptfe, bush, ring, it]     41        11
# 40                          [pvc, sleev, size, id, 4]     41        11
# 30  [capacitor, for, rc, fan, 5, med, plus, minus,...     42        50
# 34  [epoxy, fibre, glass, sheet, 1200, x, 1200, x3...     41         1
# 55                             [motor, spirit, petro]     92        11
# 78                      [mc, steel, hex, bar, 38, mm]     42         2
# 19                [10, amps, 1, way, modular, switch]     42         2
# 48                            [hard, coke, fc, 150mm]     92         1
# 86  [lamp, flourescent, day, light, bi, pin, dimen...     92        11
# 11                       [m, s, wire, 0, 90, mm, dia]     90        70
# 38             [pvc, sleeve, i, d, 35, mm, x, 01, mm]     41        11
# 41  [silicon, rubber, tape, type, htv, hbt, h5, si...     41        11
# 45                            [rtv, silicone, rubber]     41        13
# 53                 [raw, petroleum, coke, chipped, t]     92         2
# 36  [aminated, sheet, tofnol, synthetic, resing, b...     41         1
#
# [69 rows x 4 columns]

# %%
df.head(10)
# Out:
#        PL No                                        Description  \
# 54  92112006                                        FURNACE OIL
# 8   90367170                         M C HEX BAR 23.81 MM STEEL
# 50  92021025                                      Foundary Coke
# 9   90210013                                   Cross Beam Small
# 17  42010690       Plug top, 6-pin, 5A/6 A, 230V/250V, 50Hz, AC
# 90  42502101                                 PTFE BUSH/RING, IT
# 83  42010019                               PVC SLEEV SIZE ID- 4
# 88  90701008                                    MS Flat 40x6 mm
# 3   90350583                                    MS Flat 40x6 mm
# 28  42502101  Electric Ceiling Fan Capacitor Type Sweep Size...
#
#                                                  TAGS  group  subgroup
# 54                                     [furnace, oil]     92        11
# 8                 [m, c, hex, bar, 23, 81, mm, steel]     90        36
# 50                                   [foundary, coke]     92         2
# 9                                [cross, beam, small]     90        21
# 17  [plug, top, 6, pin, 5a, 6, a, 230v, 250v, 50hz...     42         1
# 90                             [ptfe, bush, ring, it]     42        50
# 83                          [pvc, sleev, size, id, 4]     42         1
# 88                               [ms, flat, 40x6, mm]     90        70
# 3                                [ms, flat, 40x6, mm]     90        35
# 28  [electric, ceiling, fan, capacitor, type, swee...     42        50
