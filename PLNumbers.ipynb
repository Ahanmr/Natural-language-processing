# %%
import pandas as pd

# %%
pd.read_csv("pl_num.csv")
# Out:
#     PL                                        DESCRIPTION UNIFIED
# 0   10  ALCO/ DLW LOCOMOTIVES B.G./M.G., WDM1/ WDM2/  ...     DLW
# 1   11                              DITTO VEHICLE PORTION     DLW
# 2   12                           DITTO ELECTRICAL PORTION     DLW
# 3   13  M.A.K./CLW  DIESEL  HYDRAULIC LOCOMOTIVES, B.G...      NR
# 4   14                             DITTO VEHICLE  PORTION      NR
# 5   15  ALCO/DLW BG/MG, WDM-1/ WDM-2/WDS-5/YDM-4/YDM-4...     DLW
# 6   16   GENERAL MOTORS WDG4/WDP4/HHP LOCO ENGINE PORTION     DLW
# 7   17  GENERAL MOTORS WDG4/WDP4/HHP LOCO VEHICLE PORTION     DLW
# 8   18  GENERAL MOTORS WDG4/WDP4/HHP LOCO ELECTRIC POR...     DLW
# 9   19   GENERAL MOTORS WDG4/WDP4/HHP LOCO HARDWARE ITEMS     DLW
# 10  20                                             Vacant     NaN
# 11  21                                             Vacant     NaN
# 12  22  D.C. ELECTRIC LOCOS, B.G/ POST-WAR,CM1/WCM2/WC...      CR
# ...
